# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nisha\\OneDrive\\Desktop\\stylumia\\proj'

# %%
os.chdir(r'C:\Users\nisha\OneDrive\Desktop\stylumia\proj\prepared_data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nisha\\OneDrive\\Desktop\\stylumia\\proj\\prepared_data'

# %%
from __future__ import print_function
import pandas as pd
import shutil
import sys

labels = pd.read_csv(r'C:\Users\nisha\OneDrive\Desktop\stylumia\extracting-attributes-from-fashion-images-2\train.csv')

train_dir =r'C:\Users\nisha\OneDrive\Desktop\stylumia\extracting-attributes-from-fashion-images-2\train'
for filename, class_name in labels.values:

    if not os.path.exists(str(class_name)):
        os.mkdir(str(class_name))
    src_path = train_dir + '/'+ filename 
    dst_path = str(class_name) + '/' + filename + '.jpeg'
    shutil.copy(src_path, dst_path)
    print("sucessful")
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...
